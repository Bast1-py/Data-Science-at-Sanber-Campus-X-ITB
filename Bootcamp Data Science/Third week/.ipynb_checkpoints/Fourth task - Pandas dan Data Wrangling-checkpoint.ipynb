# %% [markdown]
# # 1. Baca data menggunakan pandas dan convert menjadi dataframe
#
# Baca data diamond_1.csv yang telah disediakan kemudian baca dengan menggunakan library pandas. Tampilkan beberapa data awal untuk gambaran akan keseluruhan data

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('diamonds-1.csv')
# print(data)
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# view the first rows
data.head(21)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0            1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1            2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2            3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3            4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4            5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5            6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6            7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7            8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8            9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9           10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10          11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 11          12   0.23      Ideal     J     VS1   62.8   56.0    340  3.93
# ...

# %%
# view the last rows
data.tail(21)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53919       53920   0.76      Ideal     I    VVS1   62.2   55.0   2753  5.89
# 53920       53921   0.70  Very Good     E     VS2   62.4   60.0   2755  5.57
# 53921       53922   0.70  Very Good     E     VS2   62.8   60.0   2755  5.59
# 53922       53923   0.70  Very Good     D     VS1   63.1   59.0   2755  5.67
# 53923       53924   0.73      Ideal     I     VS2   61.3   56.0   2756  5.80
# 53924       53925   0.73      Ideal     I     VS2   61.6   55.0   2756  5.82
# 53925       53926   0.79      Ideal     I     SI1   61.6   56.0   2756  5.95
# 53926       53927   0.71      Ideal     E     SI1   61.9   56.0   2756  5.71
# 53927       53928   0.79       Good     F     SI1   58.1   59.0   2756  6.06
# 53928       53929   0.79    Premium     E     SI2   61.4   58.0   2756  6.03
# 53929       53930   0.71      Ideal     G     VS1   61.4   56.0   2756  5.76
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# # 2. DataFrame vs Series
# 1. Apa perbedaan Series dengan list dan dictionary
# 2. Apa perbedaan dataframe dan series
# 3. Buatlah suatu data series

# %% [markdown]
# # Answer:

# %% [markdown]
# 1. Series merupakan struktur data satu dimensi yang mirip array atau daftar dalam python. Series memiliki label atau indeks unik yang memungkinkan Anda mengakses data dengan cara yang lebih terstruktur daripada daftar biasa. Series dapat menyimpan berbagai jenis tipe data seperti integer, string, dan lain sebagainya. tipe data dari objek series ini harus seragam.
#
# Series memiliki persamaan dengan list yaitu dapat dilakukan metode slicing, yaitu mengakses/indexing pada object series tersebut.
#
# Series memiliki persamaan dengan dictionary yaitu index yang dimiliki series berguna seperti keys pada dictionary.

# %% [markdown]
# 2. Dataframe adalah struktur data dua dimensi yang dapat dianggap sebagai tabel atau lembar data. Ini terdiri dari baris dan kolom, dan setiap kolom dapat berisi tipe data yang berbeda. DataFrame adalah struktur data yang paling sering digunakan dalam analisis data, dan memungkinkan Anda untuk menyimpan, mengorganisasi, dan menganalisis data dengan cara yang sangat fleksibel.
#
# Sedangkan, Series adalah struktur data satu dimensi yang mirip dengan array atau daftar dalam Python. Series memiliki label atau indeks unik yang memungkinkan Anda mengakses data dengan cara yang lebih terstruktur daripada daftar biasa.

# %% [markdown]
# 3.

# %%
import pandas as pd
# Series: an indexed 1D array
a = pd.Series([2,4,6,8,10], 
             index = ['a', 'b', 'c', 'd', 'e'])  # Explicit index
a
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
# Access data
a['d'] = 80 # 
a
# Out:
# a     2
# b     4
# c     6
# d    80
# e    10
# dtype: int64

# %% [markdown]
# # 3. Filter DataFrame
# 1. Tampilkan dataset yang hanya menunjukkan ‘cut’ yang ‘ideal’
# 2. Pilih semua diamond dengan harga < 1000
# 3. Pilih diamond dengan ‘color’ ‘E’ dan harga lebih dari 1000

# %% [markdown]
# 1

# %%
data.cut # untuk menampilkan index dan atribut "cut" dari atas sampai bawah
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object

# %%
data.price
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
data[['cut']].head(21) # menampilkan 20 pertama dari index dan atribut "cut"
# Out:
#           cut
# 0       Ideal
# 1     Premium
# 2        Good
# 3     Premium
# 4        Good
# 5   Very Good
# 6   Very Good
# 7   Very Good
# 8        Fair
# 9   Very Good
# 10       Good
# 11      Ideal
# 12    Premium
# 13      Ideal
# 14    Premium
# 15    Premium
# 16      Ideal
# 17       Good
# 18       Good
# 19  Very Good
# 20       Good

# %%
data.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# 2

# %%
data_filtered = data[data[ 'price'] < 1000] # harga kurang dari 1000
print(data_filtered)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53635       53636   0.30      Ideal     I    VVS1   62.1   56.0    552  4.30
# 53636       53637   0.30      Ideal     D     SI1   61.6   57.0    552  4.28
# 53637       53638   0.30  Very Good     D     SI1   62.5   57.0    552  4.26
# 53638       53639   0.30      Ideal     D     SI1   61.0   57.0    552  4.29
# 53639       53640   0.30      Ideal     D     SI1   61.0   56.0    552  4.35
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data_filtered.price
# Out:
# 0        326
# 1        326
# 2        327
# 3        334
# 4        335
#         ...
# 53635    552
# 53636    552
# 53637    552
# 53638    552
# 53639    552
# Name: price, Length: 14499, dtype: int64

# %%
data.loc[:, ['color', 'price']].head(21)
# Out:
#    color  price
# 0      E    326
# 1      E    326
# 2      E    327
# 3      I    334
# 4      J    335
# 5      J    336
# 6      I    336
# 7      H    337
# 8      E    337
# 9      H    338
# 10     J    339
# 11     J    340
# 12     F    342
# 13     J    344
# 14     E    345
# 15     E    345
# 16     I    348
# 17     J    351
# 18     J    351
# 19     J    351
# 20     I    351

# %%
color = data.color == 'E'
color
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Name: color, Length: 53940, dtype: bool

# %% [markdown]
# # 4. Data Cleaning
#
# 1. Tambahkan kolom baru bernama ‘volume’ yang berisikan hasil perkalian x*y*z
# 2. Buat DataFrame baru dengan kolom ‘cut’, ‘clarity’, dan ‘price’ saja

# %% [markdown]
# # 1

# %%
data['Volume'] = data['x'] * data['y'] * data['z']
data.head(21)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0            1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1            2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2            3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3            4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4            5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5            6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6            7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7            8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8            9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9           10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10          11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 11          12   0.23      Ideal     J     VS1   62.8   56.0    340  3.93
# ...

# %% [markdown]
# # 2

# %%
import pandas as pd

cut = ['Ideal', 'Premiun', 'Vary Good', 'Good', 'Fair']
clarity = ['SI2', 'SI20', 'SI12', 'SI14', 'SI8']
price = [514, 1388, 998, 867, 1800]

df = pd.DataFrame({'Cut': cut, 'Clarity': clarity, 'Price': price})
print(df)
# Out:
#          Cut Clarity  Price
# 0      Ideal     SI2    514
# 1    Premiun    SI20   1388
# 2  Vary Good    SI12    998
# 3       Good    SI14    867
# 4       Fair     SI8   1800

# %% [markdown]
# # 5.  Menentukan jenis data categorical atau numeric
# Jelaskan data kategorikal (kualitatif) dan data numerik (kuantitatif)
#
# Jawab disini:

# %% [markdown]
# data kategorikal (kualitatif) itu data yang disajikan dalam bentuk kata-kata (tulisan), gambar (audio) atau video yang memiliki makna. Data-data tersebut diperoleh dari wawancara, pengamatan, pemotretan, perekaman dan lain-lain. Pada intinya data kualitatif adalah data yang bukan merupakan bilangan angka sehinga tidak dianalisis dengan ilmu statistik (statistika).
#
# sedangkan, data numerik (kuantitatif) itu data yang disajikan dalam bentuk bilangan angka, sehingga data kualitatif diolah secara statistik. Data kualitatif terbagi lagi menjadi dua jenis yaitu data kategorik dan data numerik. Data kategorikal ini terbagi menjadi nominal, ordinal, interval, dan rasio.
