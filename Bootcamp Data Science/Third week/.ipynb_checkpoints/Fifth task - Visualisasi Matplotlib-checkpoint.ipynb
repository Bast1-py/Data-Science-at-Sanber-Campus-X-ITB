# %% [markdown]
# Ketentuan Pengerjaan:
# *   Visualisasi diperbolehkan HANYA menggunakan MATPLOTLIB
# *   Visualisasi dibebaskan
# *   Setiap visualisasi WAJIB diinterpretasikan

# %% [markdown]
# Data Set: Retail Sales Dataset
#
# 1. Transaction ID: A unique identifier for each transaction, allowing tracking and reference.
# 2. Date: The date when the transaction occurred, providing insights into sales trends over time.
# 3. Customer ID: A unique identifier for each customer, enabling customer-centric analysis.
# 4. Gender: The gender of the customer (Male/Female), offering insights into gender-based purchasing patterns.
# 5. Age: The age of the customer, facilitating segmentation and exploration of age-related influences.
# 6. Product Category: The category of the purchased product (e.g., Electronics, Clothing, Beauty), helping understand product preferences.
# 7. Quantity: The number of units of the product purchased, contributing to insights on purchase volumes.
# 8. Price per Unit: The price of one unit of the product, aiding in calculations related to total spending.
# 9. Total Amount: The total monetary value of the transaction, showcasing the financial impact of each purchase.
#
# Source: https://www.kaggle.com/datasets/mohammadtalib786/retail-sales-dataset

# %%
'''
Import modul yang dibutuhkan
'''
# Tuliskan Kode di sini
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
'''
Read file CSV
'''

# Tuliskan Kode di sini
dataset = pd.read_csv("retail_sales_dataset.csv")
dataset
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
dataset.head(11)
# Out:
#     Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                1  2023-11-24     CUST001    Male   34           Beauty
# 1                2  2023-02-27     CUST002  Female   26         Clothing
# 2                3  2023-01-13     CUST003    Male   50      Electronics
# 3                4  2023-05-21     CUST004    Male   37         Clothing
# 4                5  2023-05-06     CUST005    Male   30           Beauty
# 5                6  2023-04-25     CUST006  Female   45           Beauty
# 6                7  2023-03-13     CUST007    Male   46         Clothing
# 7                8  2023-02-22     CUST008    Male   30      Electronics
# 8                9  2023-12-13     CUST009    Male   63      Electronics
# 9               10  2023-10-07     CUST010  Female   52         Clothing
# 10              11  2023-02-14     CUST011    Male   23         Clothing
#
#     Quantity  Price per Unit  Total Amount
# 0          3              50           150
# ...

# %%
dataset.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
dataset.nunique()
# Out:
# Transaction ID      1000
# Date                 345
# Customer ID         1000
# Gender                 2
# Age                   47
# Product Category       3
# Quantity               4
# Price per Unit         5
# Total Amount          18
# dtype: int64

# %%
dataset.Date = pd.to_datetime(dataset.Date,format = '%Y-%m-%d')
dataset['year'] = dataset.Date.dt.year
dataset['month'] = dataset.Date.dt.month
dataset['week'] = dataset.Date.dt.week
dataset['day'] = dataset.Date.dt.day
# Out:
# C:\Users\Bastian Torus\AppData\Local\Temp\ipykernel_4428\2380941080.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   dataset['week'] = dataset.Date.dt.week

# %%
dataset.head()
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount  year  month  week  day
# 0         3              50           150  2023     11    47   24
# 1         2             500          1000  2023      2     9   27
# 2         1              30            30  2023      1     2   13
# 3         1             500           500  2023      5    20   21
# 4         2              50           100  2023      5    18    6

# %%
dataset_year = dataset.groupby('year').sum().reset_index()
dataset_year.head()
# Out:
#    year  Transaction ID    Age  Quantity  Price per Unit  Total Amount  month  \
# 0  2023          499639  41295      2510          179360        454470   6547
# 1  2024             861     97         4             530          1530      2
#
#     week    day
# 0  26630  15308
# 1      2      2

# %%
dataset_monthly = dataset.groupby('month').sum().reset_index()
dataset_monthly.head()
# Out:
#    month  Transaction ID   Age  Quantity  Price per Unit  Total Amount  \
# 0      1           37728  3125       199           14645         36980
# 1      2           37699  3320       214           16255         44060
# 2      3           34712  3111       194           12620         28990
# 3      4           42755  3652       214           12715         33870
# 4      5           53821  4455       259           21255         53150
#
#      year  week   day
# 0  157796   358  1243
# 1  171955   574  1205
# 2  147679   801  1139
# 3  173978  1327  1424
# 4  212415  2060  1563

# %%
dataset_weekly = dataset.groupby('week').sum().reset_index()
dataset_weekly.head()
# Out:
#    week  Transaction ID  Age  Quantity  Price per Unit  Total Amount   year  \
# 0     1            9384  797        43            3495          7630  38439
# 1     2            9207  666        47            2275          4850  34391
# 2     3            6283  607        30            3045          8215  28322
# 3     4            8937  680        51            3275          9845  36414
# 4     5           10084  975        68            4530         13070  50575
#
#    month  day
# 0     19   82
# 1     17  215
# 2     14  266
# 3     18  464
# 4     43  276

# %%
dataset_day = dataset.groupby('day').sum().reset_index()
dataset_day.head()
# Out:
#    day  Transaction ID   Age  Quantity  Price per Unit  Total Amount   year  \
# 0    1           20518  1435       100            8935         23680  80922
# 1    2           18213  1476        91            4880         13965  72828
# 2    3           14504  1144        69            4460          9000  58667
# 3    4           17064  1288        72            6380         14150  66759
# 4    5           21330  1869        99            8170         18365  91035
#
#    month  week
# 0    251  1085
# 1    249   944
# 2    183   686
# 3    228   873
# 4    282  1066

# %%
dataset.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount  \
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000
#
#               year        month         week          day
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean   2023.002000     6.549000    26.632000    15.310000
# std       0.044699     3.452755    15.039374     8.871674
# ...

# %% [markdown]
# ### Soal 1
#
# Visualisasikan distribusi setiap fitur/variabel

# %%
# Tuliskan Kode di sini
plt.figure(figsize=(7, 16))
plt.style.use('ggplot')
ax0 = plt.subplot(511)
ax0 = plt.plot(dataset_year['year'], dataset_year['Total Amount'], label='Total Amount', marker='o')
plt.title('Line Chart: Retail Sales')
plt.xlabel('Year')
plt.ylabel('Total Amount')
plt.legend()
ax1 = plt.subplot(512)
ax1 = plt.plot(dataset_monthly['month'], dataset_monthly['Total Amount'], label='Total Amount', color='orange', marker='o')
plt.xlabel('Month')
plt.ylabel('Total Amount')
plt.legend()
ax2 = plt.subplot(513)
ax2 = plt.plot(dataset_weekly['week'], dataset_weekly['Total Amount'], label='Total Amount', color='blue', marker='o')
plt.xlabel('Week')
plt.ylabel('Total Amount')
plt.legend()
ax3 = plt.subplot(514)
ax3 = plt.plot(dataset_day['day'], dataset_day['Total Amount'], label='Total Amount', color='green', marker='o')
plt.xlabel('Day')
plt.ylabel('Total Amount')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(7, 18))
ax0 = plt.subplot(511)
ax0 = plt.hist(dataset['Age'], histtype="stepfilled", bins=20, color='red', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Customer Age')

ax1 = plt.subplot(512)
ax1 = plt.hist(dataset['Quantity'],  bins=20, color='red', edgecolor='black')
plt.xlabel('Quantity')
plt.ylabel('Frequency')

ax2 = plt.subplot(513)
ax2 = plt.hist(dataset['Total Amount'], histtype="stepfilled", bins=20, color='red', edgecolor='black')
plt.xlabel('Total Amount')
plt.ylabel('Frequency')

ax3 = plt.subplot(514)
ax3 = plt.hist(dataset['Product Category'], bins=20, color='red', edgecolor='black')
plt.xlabel('Product Category')
plt.ylabel('Frequency')

plt.show()

# %%
dataset['month'] = dataset['Date'].dt.month
jumlah_transaksi_per_bulan = dataset.groupby('month')['Transaction ID'].count()
jumlah_transaksi_per_bulan
# Out:
# month
# 1      78
# 2      85
# 3      73
# 4      86
# 5     105
# 6      77
# 7      72
# 8      94
# 9      65
# 10     96
# 11     78
# 12     91
# Name: Transaction ID, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.barh(dataset["month"],dataset["Transaction ID"])
plt.xlabel("Transaction ID")
plt.ylabel("Months")
plt.title("Monthly view of Transaction")
plt.show()

# %%
dataset.groupby(['month','Gender']).month.count()
# Out:
# month  Gender
# 1      Female    40
#        Male      38
# 2      Female    36
#        Male      49
# 3      Female    41
#        Male      32
# 4      Female    50
#        Male      36
# 5      Female    45
#        Male      60
# 6      Female    39
#        Male      38
# 7      Female    37
#        Male      35
# 8      Female    50
#        Male      44
# 9      Female    35
#        Male      30
# 10     Female    43
#        Male      53
# 11     Female    39
#        Male      39
# 12     Female    55
#        Male      36
# Name: month, dtype: int64

# %%
dataset.groupby('Product Category').Quantity.count()
# Out:
# Product Category
# Beauty         307
# Clothing       351
# Electronics    342
# Name: Quantity, dtype: int64

# %%
plt.figure(figsize=(8, 4))
product = dataset['Product Category'].value_counts()
product.plot(kind='barh', color='red')
plt.xlabel('Number of Transactions')
plt.ylabel('Product Category')
plt.title('Distribution of Product Categories')
plt.show()

# %% [markdown]
# ### Soal 2
#
# Siapakah Top 10 spender dan berapa total transaksinya?

# %%
# Tuliskan Kode di sini
plt.figure(figsize=(10,6))
plt.barh(dataset["month"],dataset["Transaction ID"])
plt.xlabel("Transaction ID")
plt.ylabel("Months")
plt.title("Monthly view of Transaction")
plt.show()

# %%
dataset['month'] = dataset['Date'].dt.month
jumlah_transaksi_per_bulan = dataset.groupby('month')['Transaction ID'].count()
jumlah_transaksi_per_bulan
# Out:
# month
# 1      78
# 2      85
# 3      73
# 4      86
# 5     105
# 6      77
# 7      72
# 8      94
# 9      65
# 10     96
# 11     78
# 12     91
# Name: Transaction ID, dtype: int64

# %%
dataset.groupby(['month','Gender']).month.count()
# Out:
# month  Gender
# 1      Female    40
#        Male      38
# 2      Female    36
#        Male      49
# 3      Female    41
#        Male      32
# 4      Female    50
#        Male      36
# 5      Female    45
#        Male      60
# 6      Female    39
#        Male      38
# 7      Female    37
#        Male      35
# 8      Female    50
#        Male      44
# 9      Female    35
#        Male      30
# 10     Female    43
#        Male      53
# 11     Female    39
#        Male      39
# 12     Female    55
#        Male      36
# Name: month, dtype: int64

# %%
plt.figure(figsize=(7, 16))
ax1 = plt.subplot(512)
ax1 = plt.plot(dataset_monthly['month'], dataset_monthly['Total Amount'], label='Total Amount', color='orange', marker='o')
plt.xlabel('Month')
plt.ylabel('Total Amount')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
dataset.groupby('Age')['Total Amount'].mean().plot(kind='bar')
plt.xlabel('Age')
plt.ylabel('Total Amount')
plt.title('Age View of Total Amount')
plt.show()

# %% [markdown]
# dari jumlah transaksi terbanyak terjadi bulan ke-5 dan memiliki customer wanita berumur 45 dan pria berumur 60. sedangkan untuk keseluruhan ditahun 2023 ini orang dengan umur 37 tahun paling banyak transaksi dan membeli produk dan yang paling sedikit berumur 39 tahun.

# %% [markdown]
# ### Soal 3
#
# Bagaimana demografi orang yang membeli barang dengan kategori elektronik?

# %%
# Tuliskan Kode di sini
plt.figure(figsize=(8, 4))
product = dataset['Product Category'].value_counts()
product.plot(kind='barh', color='red')
plt.xlabel('Number of Transactions')
plt.ylabel('Product Category')
plt.title('Distribution of Product Categories')
plt.show()

# %%
dataset.groupby('Product Category').Quantity.count()
# Out:
# Product Category
# Beauty         307
# Clothing       351
# Electronics    342
# Name: Quantity, dtype: int64

# %% [markdown]
# dalam khasus ini terdapat 3 kategori produk yang dibutuhkan customer yaitu beauty, clothing, dan elektronik. untuk produk elektronik demand cukup tinggi jika dibandingkan produk beauty namun lebih rendah jika dibandingkan produk clothing.

# %% [markdown]
# ### Soal 4
#
# Kategori produk apa yang paling signifikan dalam memberikan Gross evenue?

# %%
# Tuliskan Kode di sini
category_revenue = dataset.groupby('Product Category')['Total Amount'].sum().reset_index()
category_revenue
# Out:
#   Product Category  Total Amount
# 0           Beauty        143515
# 1         Clothing        155580
# 2      Electronics        156905

# %%
plt.figure(figsize=(10, 6))
plt.bar(category_revenue['Product Category'], category_revenue['Total Amount'])
plt.xlabel('Product Category')
plt.ylabel('Total Amount')
plt.title('Top Product Category and Total Transactions')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Soal 5
#
# Bagaimana tren penjualan dari waktu ke waktu? Apakah terdapat peningkatan di suatu tanggal tertentu?

# %% [markdown]
# Dari visualisasi line chart diatas, saya membuat visualisasi per bulan, per minggu, dan per hari.
# untuk satu tahun yang mana jumlah transaksi dan quantity terbanyak terjadi pada bulan ke-lima dan mengalamai penurunan cukup banyak di bulan ke-sembilan.
# Dan untuk satu bulan tersebut paling banyak terjadi pada range tanggal 20 - 25.

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'])

daily_sales = dataset.groupby('Date')['Total Amount'].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(daily_sales['Date'], daily_sales['Total Amount'], marker='o', linestyle='-')
plt.title('Tren Penjualan Harian')
plt.xlabel('Tanggal')
plt.ylabel('Total Penjualan')
plt.grid(True)
plt.show()

# %%
dataset['Month'] = dataset['Date'].dt.to_period('M')

monthly_sales = dataset.groupby('Month')['Total Amount'].sum()

plt.figure(figsize=(12, 6))
plt.plot(monthly_sales.index.astype(str), monthly_sales.values, marker='o', linestyle='-')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# # Soal 6
#
# Tambahkan pertanyaan analisis yang Anda inginkan, kemudian jawab..

# %%
# Tuliskan Kode di sini
