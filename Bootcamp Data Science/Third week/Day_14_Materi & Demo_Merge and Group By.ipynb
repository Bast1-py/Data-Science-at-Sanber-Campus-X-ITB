# %% [markdown]
# # Data Merging

# %% [markdown]
# ## concat()

# %%
import pandas as pd

df1=pd.DataFrame({'id_siswa':['A001','A002','A003','A004'],
                  'Kelas':['12A','12B','12C','12D'],
                  'Nilai':[100,98,96,95],
                  'Peringkat':[1,2,3,4]},
                 index=[0, 1, 2, 3])

df2=pd.DataFrame({'id_siswa':['A005','A006','A007','A008'],
                  'Kelas':['12E','12F','12G','12H'],
                  'Nilai':[90,88,86,85],
                  'Peringkat':[5,6,7,8]},
                 index=[4, 5, 6, 7])

df3=pd.DataFrame({'id_siswa':['A009','A010','A011','A012'],
                  'Kelas':['12I','12J','12K','12L'],
                  'Nilai':[80,75,73,70],
                  'Peringkat':[9,10,11,12]},
                 index=[8, 9, 10, 11])

print(df1)
print(df2)
print(df3)
# Out:
#   id_siswa Kelas  Nilai  Peringkat
# 0     A001   12A    100          1
# 1     A002   12B     98          2
# 2     A003   12C     96          3
# 3     A004   12D     95          4
#   id_siswa Kelas  Nilai  Peringkat
# 4     A005   12E     90          5
# 5     A006   12F     88          6
# 6     A007   12G     86          7
# 7     A008   12H     85          8
#    id_siswa Kelas  Nilai  Peringkat
# 8      A009   12I     80          9
# 9      A010   12J     75         10
# 10     A011   12K     73         11
# 11     A012   12L     70         12

# %%
# penggabungan berdasarkan baris
pd.concat([df1, df2, df3])
# Out:
#    id_siswa Kelas  Nilai  Peringkat
# 0      A001   12A    100          1
# 1      A002   12B     98          2
# 2      A003   12C     96          3
# 3      A004   12D     95          4
# 4      A005   12E     90          5
# 5      A006   12F     88          6
# 6      A007   12G     86          7
# 7      A008   12H     85          8
# 8      A009   12I     80          9
# 9      A010   12J     75         10
# 10     A011   12K     73         11
# 11     A012   12L     70         12

# %%
# penggabungan berdasarkan kolom
pd.concat([df1, df2, df3], axis=1)

# %% [markdown]
# ## Logika Penggabungan

# %%
df1 = pd.DataFrame({'id_siswa': ['A001', 'A002', 'A003', 'A004'],
                    'Kelas': ['12A', '12B', '12C', '12D'],
                    'Tinggi siswa (cm)': [155, 160, 170, 165 ]},
                     index=[0, 1, 2, 3])
df2 = pd.DataFrame({'id_siswa': ['A001', 'A002', 'A005', 'A006'],
                    'Nilai': [100, 98, 96, 95 ],
                    'Peringkat': [1, 2, 3, 4]},
                   index=[4, 5, 6, 7])

print(df1)
print(df2)
# Out:
#   id_siswa Kelas  Tinggi siswa (cm)
# 0     A001   12A                155
# 1     A002   12B                160
# 2     A003   12C                170
# 3     A004   12D                165
#   id_siswa  Nilai  Peringkat
# 4     A001    100          1
# 5     A002     98          2
# 6     A005     96          3
# 7     A006     95          4

# %% [markdown]
# ### Full outer join

# %%
pd.merge(df1,df2,on='id_siswa',how='outer')
# Out:
#   id_siswa Kelas  Tinggi siswa (cm)  Nilai  Peringkat
# 0     A001   12A              155.0  100.0        1.0
# 1     A002   12B              160.0   98.0        2.0
# 2     A003   12C              170.0    NaN        NaN
# 3     A004   12D              165.0    NaN        NaN
# 4     A005   NaN                NaN   96.0        3.0
# 5     A006   NaN                NaN   95.0        4.0

# %%
df1.join(df2, how='outer', lsuffix="_left", rsuffix="_right")
# Out:
#   id_siswa_left Kelas  Tinggi siswa (cm) id_siswa_right  Nilai  Peringkat
# 0          A001   12A              155.0            NaN    NaN        NaN
# 1          A002   12B              160.0            NaN    NaN        NaN
# 2          A003   12C              170.0            NaN    NaN        NaN
# 3          A004   12D              165.0            NaN    NaN        NaN
# 4           NaN   NaN                NaN           A001  100.0        1.0
# 5           NaN   NaN                NaN           A002   98.0        2.0
# 6           NaN   NaN                NaN           A005   96.0        3.0
# 7           NaN   NaN                NaN           A006   95.0        4.0

# %% [markdown]
# ### Inner join

# %%
pd.merge(df1,df2,on='id_siswa',how='inner')
# Out:
#   id_siswa Kelas  Tinggi siswa (cm)  Nilai  Peringkat
# 0     A001   12A                155    100          1
# 1     A002   12B                160     98          2

# %% [markdown]
# ### Left join

# %%
pd.merge(df1,df2,on='id_siswa',how='left')
# Out:
#   id_siswa Kelas  Tinggi siswa (cm)  Nilai  Peringkat
# 0     A001   12A                155  100.0        1.0
# 1     A002   12B                160   98.0        2.0
# 2     A003   12C                170    NaN        NaN
# 3     A004   12D                165    NaN        NaN

# %% [markdown]
# ### Right join

# %%
pd.merge(df1,df2,on='id_siswa',how='right')
# Out:
#   id_siswa Kelas  Tinggi siswa (cm)  Nilai  Peringkat
# 0     A001   12A              155.0    100          1
# 1     A002   12B              160.0     98          2
# 2     A005   NaN                NaN     96          3
# 3     A006   NaN                NaN     95          4

# %% [markdown]
# # Group By

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame([('bird', 'Falconiformes', 389.0),
                    ('bird', 'Psittaciformes', 24.0),
                    ('mammal', 'Carnivora', 80.2),
                    ('mammal', 'Primates', np.nan),
                    ('mammal', 'Carnivora', 58)],
                    index=['falcon', 'parrot', 'lion', 'monkey', 'leopard'],
                    columns=('class', 'order', 'max_speed'))

df
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0

# %%
df.groupby('class').mean()
# Out:
# <ipython-input-12-b899bca78c00>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('class').mean()
#         max_speed
# class
# bird        206.5
# mammal       69.1

# %%
df.groupby(['class', 'order'])[['max_speed']].agg(['mean', 'sum'])
# Out:
#                       max_speed
#                            mean    sum
# class  order
# bird   Falconiformes      389.0  389.0
#        Psittaciformes      24.0   24.0
# mammal Carnivora           69.1  138.2
#        Primates             NaN    0.0

# %% [markdown]
# # Case Example

# %%
df = pd.read_csv('/content/drive/MyDrive/SanberCode X ITB/Data Wrangling Dataset/Dataset/Employee_Data.csv')
df
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
df_group=df.groupby('dept')['average_montly_hours'].agg(['mean', 'max'])

# %%
df_group.reset_index().sort_values(['mean', 'max'],ascending=False).set_index(['dept'])
# Out:
#                    mean    max
# dept
# technical    202.497426  310.0
# IT           202.215974  308.0
# management   201.249206  307.0
# accounting   201.162973  310.0
# sales        200.911353  310.0
# RandD        200.800508  308.0
# support      200.758188  310.0
# product_mng  199.965632  310.0
# marketing    199.385781  310.0
# hr           198.684709  310.0
