# %% [markdown]
# # Klustering

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("pokemon.csv")
# Preview the first 5 lines of the loaded data
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Unnamed: 0  #                    Name          Type  Total  HP  Attack  \
# 0           1  1               Bulbasaur  Grass Poison    318  45      49
# 1           2  2                 Ivysaur  Grass Poison    405  60      62
# 2           3  3                Venusaur  Grass Poison    525  80      82
# 3           4  3  Venusaur Mega Venusaur  Grass Poison    625  80     100
# 4           5  4              Charmander         Fire     309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed
# 0       49       65       65     45
# 1       63       80       80     60
# 2       83      100      100     80
# 3      123      122      120     80
# 4       43       60       50     65

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  594 non-null    int64
#  1   #           594 non-null    int64
#  2   Name        594 non-null    object
#  3   Type        594 non-null    object
#  4   Total       594 non-null    int64
#  5   HP          594 non-null    int64
#  6   Attack      594 non-null    int64
#  7   Defense     594 non-null    int64
#  8   Sp. Atk     594 non-null    int64
#  9   Sp. Def     594 non-null    int64
#  10  Speed       594 non-null    int64
# dtypes: int64(9), object(2)
# memory usage: 51.2+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
    data["Attack"] = pd.to_numeric(data["Attack"])
    data["Defense"] = pd.to_numeric(data["Defense"])

    #menambahkan dua kolom tranformasi
    data["Alog"] = np.log(data["Attack"])
    data["Dlog"] = np.log(data["Defense"])

    data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Unnamed: 0  #                    Name          Type  Total  HP  Attack  \
# 0           1  1               Bulbasaur  Grass Poison    318  45      49
# 1           2  2                 Ivysaur  Grass Poison    405  60      62
# 2           3  3                Venusaur  Grass Poison    525  80      82
# 3           4  3  Venusaur Mega Venusaur  Grass Poison    625  80     100
# 4           5  4              Charmander         Fire     309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed      Alog      Dlog
# 0       49       65       65     45  3.891820  3.891820
# 1       63       80       80     60  4.127134  4.143135
# 2       83      100      100     80  4.406719  4.418841
# 3      123      122      120     80  4.605170  4.812184
# 4       43       60       50     65  3.951244  3.761200

# %%
np.log?

# %%
log_data = data.iloc[:, 11:13]
log_data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Alog      Dlog
# 0  3.891820  3.891820
# 1  4.127134  4.143135
# 2  4.406719  4.418841
# 3  4.605170  4.812184
# 4  3.951244  3.761200

# %%
log_array = np.array(log_data)
log_array
# Out:
# array([[3.8918203 , 3.8918203 ],
#        [4.12713439, 4.14313473],
#        [4.40671925, 4.41884061],
#        ...,
#        [4.14313473, 3.80666249],
#        [4.53259949, 4.00733319],
#        [4.81218436, 4.17438727]])

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

kmeans = KMeans(n_clusters=3, random_state=200)
kmeans.fit(log_array)
data['kluster'] = kmeans.labels_
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    Unnamed: 0  #                    Name          Type  Total  HP  Attack  \
# 0           1  1               Bulbasaur  Grass Poison    318  45      49
# 1           2  2                 Ivysaur  Grass Poison    405  60      62
# 2           3  3                Venusaur  Grass Poison    525  80      82
# 3           4  3  Venusaur Mega Venusaur  Grass Poison    625  80     100
# 4           5  4              Charmander         Fire     309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed      Alog      Dlog  kluster
# 0       49       65       65     45  3.891820  3.891820        2
# 1       63       80       80     60  4.127134  4.143135        2
# 2       83      100      100     80  4.406719  4.418841        0
# 3      123      122      120     80  4.605170  4.812184        0
# 4       43       60       50     65  3.951244  3.761200        2

# %%
kmeans.fit?

# %%
plt.scatter(data.Attack, data.Defense, s = 20, c = data.kluster, marker = "o", alpha = 0.5)
plt.title("Hasil Klustering K-Means")
plt.xlabel("Atk")
plt.ylabel("Def")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Menentukan K

# %%
make_blobs?

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=1000, centers=3, n_features=2, shuffle=True, random_state=31)
plt.scatter(X[:, 0], X[:, 1], s = 20, marker = "o", alpha = 0.8)
plt.show()

# %% [markdown]
# ## Elbow Method

# %%
sse = []
k_list = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k).fit(X)
    centroids = kmeans.cluster_centers_
    prediksi = kmeans.predict(X)
    nilai_sse = 0

    for i in range(len(X)):
        titik_pusat = centroids[prediksi[i]]
        nilai_sse += (X[i, 0] - titik_pusat[0]) ** 2 + (X[i, 1] - titik_pusat[1]) ** 2

    sse.append(nilai_sse)
    k_list.append(k)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
  plt.plot(k_list,sse)
  plt.show()

# %% [markdown]
# ## Silhouette Method

# %%
from sklearn.metrics import silhouette_score

data = []
k_list = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters = k).fit(X)
    labels = kmeans.labels_
    data.append(silhouette_score(X, labels, metric = 'euclidean'))
    k_list.append(k)

plt.plot(k_list,data)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # Apriori

# %%
# Data belanjaan

data_belanjaan = [
  ['Roti', 'Susu', 'Telur'],
  ['Roti', 'Keju'],
  ['Roti', 'Mentega', 'Telur'],
  ['Susu', 'Keju', 'Telur'],
  ['Roti', 'Susu'],
  ['Roti', 'Keju', 'Telur'],
  ['Roti', 'Susu', 'Mentega'],
  ['Keju', 'Mentega'],
  ['Roti', 'Susu', 'Keju'],
  ['Telur', 'Mentega'],
  ['Susu', 'Keju', 'Mentega'],
  ['Roti', 'Telur'],
  ['Roti', 'Susu', 'Keju', 'Mentega', 'Telur'],
  ['Susu', 'Keju'],
  ['Roti', 'Susu', 'Mentega', 'Telur'],
  ['Roti', 'Keju', 'Mentega'],
  ['Susu', 'Telur'],
  ['Roti', 'Susu', 'Keju'],
  ['Keju', 'Mentega', 'Telur'],
  ['Roti', 'Susu', 'Keju', 'Telur'],
  ['Roti', 'Susu', 'Keju', 'Mentega'],
  ['Roti', 'Keju', 'Mentega', 'Telur'],
  ['Roti', 'Keju', 'Telur'],
  ['Susu', 'Mentega', 'Telur'],
  ['Roti', 'Susu', 'Mentega', 'Keju'],
  ['Roti', 'Mentega'],
  ['Keju', 'Telur'],
  ['Roti', 'Susu', 'Keju', 'Mentega', 'Telur'],
  ['Roti', 'Keju', 'Telur'],
  ['Roti', 'Susu', 'Mentega']
]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

# %%
te = TransactionEncoder()
te_ary = te.fit(data_belanjaan).transform(data_belanjaan)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Keju  Mentega   Roti   Susu  Telur
# 0   False    False   True   True   True
# 1    True    False   True  False  False
# 2   False     True   True  False   True
# 3    True    False  False   True   True
# 4   False    False   True   True  False
# 5    True    False   True  False   True
# 6   False     True   True   True  False
# 7    True     True  False  False  False
# 8    True    False   True   True  False
# 9   False     True  False  False   True
# 10   True     True  False   True  False
# 11  False    False   True  False   True
# 12   True     True   True   True   True
# 13   True    False  False   True  False
# 14  False     True   True   True   True
# 15   True     True   True  False  False
# 16  False    False  False   True   True
# 17   True    False   True   True  False
# 18   True     True  False  False   True
# 19   True    False   True   True   True
# 20   True     True   True   True  False
# 21   True     True   True  False   True
# 22   True    False   True  False   True
# 23  False     True  False   True   True
# 24   True     True   True   True  False
# 25  False     True   True  False  False
# 26   True    False  False  False   True
# 27   True     True   True   True   True
# 28   True    False   True  False   True
# 29  False     True   True   True  False

# %%
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)

# Menampilkan frequent itemsets
print("Frequent Itemsets:")
display(frequent_itemsets)
# Out:
# Frequent Itemsets:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support               itemsets
# 0   0.633333                 (Keju)
# 1   0.533333              (Mentega)
# 2   0.700000                 (Roti)
# 3   0.566667                 (Susu)
# 4   0.566667                (Telur)
# 5   0.300000        (Keju, Mentega)
# 6   0.433333           (Keju, Roti)
# 7   0.333333           (Keju, Susu)
# 8   0.333333          (Keju, Telur)
# 9   0.366667        (Mentega, Roti)
# 10  0.300000        (Mentega, Susu)
# 11  0.266667       (Telur, Mentega)
# 12  0.400000           (Roti, Susu)
# 13  0.366667          (Telur, Roti)
# 14  0.266667          (Telur, Susu)
# 15  0.200000  (Keju, Mentega, Roti)
# 16  0.233333     (Keju, Roti, Susu)
# 17  0.233333    (Keju, Roti, Telur)
# 18  0.233333  (Mentega, Susu, Roti)

# %%
# Mencari asosiasi aturan dengan confidence >= 0.7
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# Menampilkan asosiasi aturan
print("\nAssociation Rules:")
display(rules)
# Out:
# Association Rules:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        antecedents consequents  antecedent support  consequent support  \
# 0           (Susu)      (Roti)            0.566667                 0.7
# 1     (Keju, Susu)      (Roti)            0.333333                 0.7
# 2    (Keju, Telur)      (Roti)            0.333333                 0.7
# 3  (Mentega, Susu)      (Roti)            0.300000                 0.7
#
#     support  confidence      lift      leverage  conviction  zhangs_metric
# 0  0.400000    0.705882  1.008403  3.333333e-03        1.02   1.923077e-02
# 1  0.233333    0.700000  1.000000  2.775558e-17        1.00   1.784287e-16
# 2  0.233333    0.700000  1.000000  2.775558e-17        1.00   1.784287e-16
# 3  0.233333    0.777778  1.111111  2.333333e-02        1.35   1.428571e-01
