# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression, ElasticNet, HuberRegressor, RANSACRegressor, TheilSenRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# # Data Undertanding
#
# Penjelasan data lebih lengkap:
# https://www.kaggle.com/datasets/rajatdey/jaipur-weather-forecasting?select=JaipurFinalCleanData.csv

# %%
df = pd.read_csv('JaipurFinalCleanData.csv')
df.head()
# Out:
#          date  meantempm  maxtempm  mintempm  meantempm_1  meantempm_2  \
# 0  2016-05-04         34        41        27         35.0         36.0
# 1  2016-05-05         31        38        24         34.0         35.0
# 2  2016-05-06         28        34        21         31.0         34.0
# 3  2016-05-07         30        38        23         28.0         31.0
# 4  2016-05-08         34        41        26         30.0         28.0
#
#    meantempm_3  meandewptm_1  meandewptm_2  meandewptm_3  ...  mindewptm_3  \
# 0         34.0           6.0           4.0          -1.0  ...        -10.0
# 1         36.0           7.0           6.0           4.0  ...         -2.0
# 2         35.0          11.0           7.0           6.0  ...         -2.0
# 3         34.0          13.0          11.0           7.0  ...          0.0
# 4         31.0          10.0          13.0          11.0  ...          6.0
#
#    maxpressurem_1  maxpressurem_2  maxpressurem_3  minpressurem_1  \
# ...

# %%
df.shape
# Out:
# (676, 40)

# %%
df.describe(include='all')
# Out:
#               date   meantempm    maxtempm    mintempm  meantempm_1  \
# count          676  676.000000  676.000000  676.000000   676.000000
# unique         676         NaN         NaN         NaN          NaN
# top     2016-05-04         NaN         NaN         NaN          NaN
# freq             1         NaN         NaN         NaN          NaN
# mean           NaN   26.053254   32.523669   19.630178    26.066568
# std            NaN    6.208964    5.987966    6.825827     6.218491
# min            NaN   10.000000   18.000000    3.000000    10.000000
# 25%            NaN   20.000000   28.000000   13.000000    20.000000
# 50%            NaN   28.000000   33.000000   22.000000    28.000000
# 75%            NaN   30.000000   37.000000   25.000000    30.000000
# max            NaN   38.000000   46.000000   32.000000    38.000000
#
#         meantempm_2  meantempm_3  meandewptm_1  meandewptm_2  meandewptm_3  \
# ...

# %%
'''
Data Numerikal
'''

num_df = df.select_dtypes(include=['int64', 'float64'])
num_df.head()
# Out:
#    meantempm  maxtempm  mintempm  meantempm_1  meantempm_2  meantempm_3  \
# 0         34        41        27         35.0         36.0         34.0
# 1         31        38        24         34.0         35.0         36.0
# 2         28        34        21         31.0         34.0         35.0
# 3         30        38        23         28.0         31.0         34.0
# 4         34        41        26         30.0         28.0         31.0
#
#    meandewptm_1  meandewptm_2  meandewptm_3  meanpressurem_1  ...  \
# 0           6.0           4.0          -1.0          1006.00  ...
# 1           7.0           6.0           4.0          1005.65  ...
# 2          11.0           7.0           6.0          1007.94  ...
# 3          13.0          11.0           7.0          1008.39  ...
# 4          10.0          13.0          11.0          1007.62  ...
#
#    mindewptm_3  maxpressurem_1  maxpressurem_2  maxpressurem_3  \
# 0        -10.0          1009.0          1008.0          1009.0
# ...

# %%
'''
Data kategorikal
'''

cat_df = df.drop(num_df, axis = 1)
cat_df.head()
# Out:
#          date
# 0  2016-05-04
# 1  2016-05-05
# 2  2016-05-06
# 3  2016-05-07
# 4  2016-05-08

# %%
def check_values(df):
    data = []
    for col in df.columns:
        data.append([col, \
                  df[col].dtype, \
                  df[col].isna().sum(), \
                  round(100*(df[col].isna().sum()/len(df)), 2), \
                  df[col].nunique(), \
                  df[col].unique()
                  ])

    return pd.DataFrame(columns=['kolom', 'dataType', 'null', 'nullPercentage', 'unique', 'values'], data=data)

# %%
check_values(df)
# Out:
#               kolom dataType  null  nullPercentage  unique  \
# 0              date   object     0             0.0     676
# 1         meantempm    int64     0             0.0      28
# 2          maxtempm    int64     0             0.0      29
# 3          mintempm    int64     0             0.0      30
# 4       meantempm_1  float64     0             0.0      28
# 5       meantempm_2  float64     0             0.0      28
# 6       meantempm_3  float64     0             0.0      28
# 7      meandewptm_1  float64     0             0.0      34
# 8      meandewptm_2  float64     0             0.0      34
# 9      meandewptm_3  float64     0             0.0      34
# 10  meanpressurem_1  float64     0             0.0     590
# 11  meanpressurem_2  float64     0             0.0     590
# 12  meanpressurem_3  float64     0             0.0     590
# 13    maxhumidity_1  float64     0             0.0      75
# 14    maxhumidity_2  float64     0             0.0      75
# ...

# %%
df.columns
# Out:
# Index(['date', 'meantempm', 'maxtempm', 'mintempm', 'meantempm_1',
#        'meantempm_2', 'meantempm_3', 'meandewptm_1', 'meandewptm_2',
#        'meandewptm_3', 'meanpressurem_1', 'meanpressurem_2', 'meanpressurem_3',
#        'maxhumidity_1', 'maxhumidity_2', 'maxhumidity_3', 'minhumidity_1',
#        'minhumidity_2', 'minhumidity_3', 'maxtempm_1', 'maxtempm_2',
#        'maxtempm_3', 'mintempm_1', 'mintempm_2', 'mintempm_3', 'maxdewptm_1',
#        'maxdewptm_2', 'maxdewptm_3', 'mindewptm_1', 'mindewptm_2',
#        'mindewptm_3', 'maxpressurem_1', 'maxpressurem_2', 'maxpressurem_3',
#        'minpressurem_1', 'minpressurem_2', 'minpressurem_3', 'precipm_1',
#        'precipm_2', 'precipm_3'],
#       dtype='object')

# %%
df.shape
# Out:
# (676, 40)

# %% [markdown]
# # Hands-On

# %%
'''
Mengubah date menjadi tipedata datetime
'''

df['date'] = pd.to_datetime(df['date'], dayfirst=True, errors='coerce')

# %%
check_values(df)
# Out:
#               kolom        dataType  null  nullPercentage  unique  \
# 0              date  datetime64[ns]     0            0.00     676
# 1         meantempm           int64     0            0.00      28
# 2          maxtempm           int64     0            0.00      29
# 3          mintempm           int64     0            0.00      30
# 4       meantempm_1         float64     0            0.00      28
# 5       meantempm_2         float64     0            0.00      28
# 6       meantempm_3         float64     0            0.00      28
# 7      meandewptm_1         float64     0            0.00      34
# 8      meandewptm_2         float64     0            0.00      34
# 9      meandewptm_3         float64     0            0.00      34
# 10  meanpressurem_1         float64     0            0.00     590
# 11  meanpressurem_2         float64     0            0.00     590
# 12  meanpressurem_3         float64     0            0.00     590
# ...

# %%
'''
Membuat kolom baru tempdiff yang berisi perbedaan rata-rata hari ini dan sebelumnya
'''

df['tempdiff'] = df['meantempm'].diff() # Feature Engineering

# %%
df['tempdiff']
# Out:
# date
# 2016-05-04    NaN
# 2016-05-05   -3.0
# 2016-05-06   -3.0
# 2016-05-07    2.0
# 2016-05-08    4.0
#              ...
# 2018-03-07    2.0
# 2018-03-08    0.0
# 2018-03-09    2.0
# 2018-03-10    0.0
# 2018-03-11    0.0
# Name: tempdiff, Length: 676, dtype: float64

# %%
'''
Melakukan grouping quarterly dan mengetahui rata-rata temp terendah, tertinggi, dan rata-ratanya.
'''

result = df.groupby(pd.Grouper(key='date', freq='Q')).agg({
    'meantempm': ['min', 'max', 'mean']
}).reset_index()

# %%
result
# Out:
#         date meantempm
#                    min max       mean
# 0 2016-06-30        28  38  34.672414
# 1 2016-09-30        24  34  28.608696
# 2 2016-12-31        16  31  22.771739
# 3 2017-03-31        10  32  20.133333
# 4 2017-06-30        26  38  32.527473
# 5 2017-09-30        24  33  29.131868
# 6 2017-12-31        16  32  22.532609
# 7 2018-03-31        14  27  19.685714

# %%
df.index = df.date

# %%
'''
Visualisasikan data dari waktu ke waktu secara seasonal

Tipe visualisasi:
Alasan:
Interpretasi:

'''

from statsmodels.graphics.tsaplots import quarter_plot

resampled = df['meantempm'].resample('Q').mean()
quarter_plot(resampled)

# %%
df['Year'] = df['date'].dt.year
df['Month'] = df['date'].dt.month

# %%
df.columns
# Out:
# Index(['date', 'meantempm', 'maxtempm', 'mintempm', 'meantempm_1',
#        'meantempm_2', 'meantempm_3', 'meandewptm_1', 'meandewptm_2',
#        'meandewptm_3', 'meanpressurem_1', 'meanpressurem_2', 'meanpressurem_3',
#        'maxhumidity_1', 'maxhumidity_2', 'maxhumidity_3', 'minhumidity_1',
#        'minhumidity_2', 'minhumidity_3', 'maxtempm_1', 'maxtempm_2',
#        'maxtempm_3', 'mintempm_1', 'mintempm_2', 'mintempm_3', 'maxdewptm_1',
#        'maxdewptm_2', 'maxdewptm_3', 'mindewptm_1', 'mindewptm_2',
#        'mindewptm_3', 'maxpressurem_1', 'maxpressurem_2', 'maxpressurem_3',
#        'minpressurem_1', 'minpressurem_2', 'minpressurem_3', 'precipm_1',
#        'precipm_2', 'precipm_3', 'tempdiff', 'Year', 'Month'],
#       dtype='object')

# %%
df
# Out:
#                  date  meantempm  maxtempm  mintempm  meantempm_1  \
# date
# 2016-05-04 2016-05-04         34        41        27         35.0
# 2016-05-05 2016-05-05         31        38        24         34.0
# 2016-05-06 2016-05-06         28        34        21         31.0
# 2016-05-07 2016-05-07         30        38        23         28.0
# 2016-05-08 2016-05-08         34        41        26         30.0
# ...               ...        ...       ...       ...          ...
# 2018-03-07 2018-03-07         24        32        15         22.0
# 2018-03-08 2018-03-08         24        32        15         24.0
# 2018-03-09 2018-03-09         26        33        19         24.0
# 2018-03-10 2018-03-10         26        34        19         26.0
# 2018-03-11 2018-03-11         26        34        18         26.0
#
#             meantempm_2  meantempm_3  meandewptm_1  meandewptm_2  \
# date
# 2016-05-04         36.0         34.0           6.0           4.0
# ...

# %%
temp = df.groupby(['Year', 'Month'])['meantempm'].mean()
temp
# Out:
# Year  Month
# 2016  5        34.250000
#       6        35.066667
#       7        29.516129
#       8        27.419355
#       9        28.900000
#       10       27.483871
#       11       21.900000
#       12       18.903226
# 2017  1        15.741935
#       2        19.928571
#       3        24.709677
#       4        31.866667
#       5        33.774194
#       6        31.900000
#       7        29.400000
#       8        28.387097
#       9        29.633333
#       10       28.419355
#       11       21.466667
#       12       17.677419
# 2018  1        16.774194
#       2        20.821429
#       3        25.000000
# Name: meantempm, dtype: float64

# %%
meantemp_marix = df.groupby(['Year', 'Month'])['meantempm'].mean().unstack()
meantemp_marix
# Out:
# Month         1          2          3          4          5          6   \
# Year
# 2016         NaN        NaN        NaN        NaN  34.250000  35.066667
# 2017   15.741935  19.928571  24.709677  31.866667  33.774194  31.900000
# 2018   16.774194  20.821429  25.000000        NaN        NaN        NaN
#
# Month         7          8          9          10         11         12
# Year
# 2016   29.516129  27.419355  28.900000  27.483871  21.900000  18.903226
# 2017   29.400000  28.387097  29.633333  28.419355  21.466667  17.677419
# 2018         NaN        NaN        NaN        NaN        NaN        NaN

# %%
'''
Visualisasikan data dari waktu ke waktu menggunakan heatmap

Tipe visualisasi:
Alasan:
Interpretasi:

'''

plt.figure(figsize=(12, 8))
sns.heatmap(meantemp_marix, cmap="YlGnBu", annot=True, fmt=".2f", linewidths=.5)

plt.xlabel('Month')
plt.ylabel('Year')
plt.title('Mean Temperature Heatmap')

plt.show()
