# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Cara membuat Multiple Subplots

# %%
plt.subplots?

# %%
fig, ax = plt.subplots()
data_x1 = [1, 2, 3, 4]
data_y1 = [10, 20, 25, 30]
data_x2 = [1, 2, 3, 4, 5]
data_y2 = [5, 15, 20, 25, 30]
ax.plot(data_x1, data_y1)
ax.plot(data_x2, data_y2)
plt.show()

# %%
fig, ax = plt.subplots()
data_x1 = [1, 2, 3, 4]
data_y1 = [10, 20, 25, 30]
data_x2 = [1, 2, 3, 4, 5]
data_y2 = [800, 1005, 900, 195, 700]
ax.plot(data_x1, data_y1)
ax.plot(data_x2, data_y2)
plt.show()

# %%
data_x1 = [1, 2, 3, 4]
data_y1 = [10, 20, 25, 30]
data_x2 = [1, 2, 3, 4, 5]
data_y2 = [20, 25, 20, 40, 50]
data_x3 = data_x2
data_y3 = [50, 10, 30, 15, 30]
data_x4 = data_x2
data_y4 = [10, 40, 24, 30, 29]

fig, ax = plt.subplots()
ax.plot(data_x1, data_y1)
ax.plot(data_x2, data_y2)
ax.plot(data_x3, data_y3)
ax.plot(data_x4, data_y4)
plt.show()

# %%
plt.plot?

# %% [markdown]
# # plt.axes()

# %%
plt.subplots?

# %%
plt.figure(figsize=(12,8))
x = np.linspace(0, 10, 20) # 0, 0.5, 1, ..., 10
ax = plt.axes()
ax2 = plt.axes((0.67, 0.67, 0.2, 0.2))
ax.plot(x, x+1)
ax2.plot(x, np.cos(x))

# %% [markdown]
# # fig.add_axes

# %%
fig.add_axes?

# %%
x = np.arange(10) # 0, 1, 2, 3.., 9
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])
ax1.plot(x, np.cos(x))
ax2.plot(x, np.sin(x))

# %% [markdown]
# # plt.subplot

# %%
plt.text?

# %%
plt.subplot(1,2,4)
 # baris 1, kolom 2, posisi ke 1
plt.text(0.5, 0.5, str((1,2,1)), fontsize=18, ha='center')
plt.subplot(1,2,2)
 # # baris 1, kolom 2, posisi ke 2
plt.text(0.5, 0.5, str((1,2,2)), fontsize=18, ha='center')
# Out:
# Text(0.5, 0.5, '(1, 2, 2)')

# %%
plt.subplot?

# %%
plt.figure(figsize=(12,8))
for i in range(1,7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2,3,i)), fontsize=18, ha='center')

# %% [markdown]
# # plt.subplots

# %%
fig, ax = plt.subplots(nrows=3, ncols=2)
print('Figure ini memiliki {0} axis di baris dan {1} axis di column'.format(ax.shape[0], ax.shape[1]))
print(ax)
# Out:
# Figure ini memiliki 3 axis di baris dan 2 axis di column
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %%
plt.xticks(np.arange(0, 11, step=1))?
# Out:
# Object `plt.set_xscale` not found.

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(12,8))
ax = ax.flatten()

for i in range(6):
    ax[i].set_xlim([0, 5])
    ax[i].set_ylim([0, 5])
    ax[i].text(2.5, 2.5, str((2,3,i)), fontsize=18, ha='center')

# %% [markdown]
# # coba

# %%
import matplotlib.pyplot as plt

data_x1 = [1, 2, 3, 4]
data_y1 = [10, 20, 25, 30]
data_x2 = [1, 2, 3, 4, 5]
data_y2 = [20, 25, 20, 40, 50]
data_x3 = data_x2
data_y3 = [50, 10, 30, 15, 30]
data_x4 = data_x2
data_y4 = [10, 40, 24, 30, 29]

fig, ax = plt.subplots(nrows=2, ncols=2)
ax[0][0].plot(data_x1, data_y1)
ax[0][1].plot(data_x2, data_y2)
ax[1][0].plot(data_x3, data_y3)
ax[1][1].plot(data_x4, data_y4)
plt.show()

# %% [markdown]
# # Improve the figures

# %%
data_x1 = [1, 2, 3, 4]
data_y1 = [10, 20, 25, 30]
data_x2 = [1, 2, 3, 4, 5]
data_y2 = [20, 25, 20, 40, 50]
data_x3 = data_x2
data_y3 = [50, 10, 30, 15, 30]
data_x4 = data_x2
data_y4 = [10, 40, 24, 30, 29]

fig, ax = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True)
ax[0][0].plot(data_x1, data_y1)
ax[0][1].plot(data_x2, data_y2)
ax[1][0].plot(data_x3, data_y3)
ax[1][1].plot(data_x4, data_y4)
plt.show()

# %% [markdown]
# # inset.axes()

# %%
# Out:
# Object `ax.inset_axes` not found.

# %%
fig, ax = plt.subplots(figsize=(8,7))
x = np.linspace(0, 10, 20)
ax.plot(x, np.sin(x))

ins1 = ax.inset_axes([0.9, 0.9, 0.3, 0.3])
ins1.plot(x, np.cos(x))

ins2 = ax.inset_axes([-0.1, 0.9, 0.3, 0.3])
ins2.plot(x, np.tan(x))

plt.show()

# %% [markdown]
# # Grid spec

# %%
plt.GridSpec?

# %%
grid = plt.GridSpec(2, 3, wspace=0.3, hspace = 0.3)

plt.figure(figsize=(12,8))
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);
